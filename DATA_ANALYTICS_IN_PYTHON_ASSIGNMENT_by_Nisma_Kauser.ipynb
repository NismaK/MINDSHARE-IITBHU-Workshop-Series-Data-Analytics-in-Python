# %% [markdown]
# <a href="https://colab.research.google.com/github/NismaK/MINDSHARE-IITBHU-Workshop-Series-Data-Analytics-in-Python/blob/main/DATA_ANALYTICS_IN_PYTHON_ASSIGNMENT_by_Nisma_Kauser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MINDSHARE – IITBHU Workshop Series**
#
# ---
#
#
# Data Analytics in Python
# Assignment for Workshop Completion
#
# BY: NISMA KAUSER

# %% [markdown]
# ### **1. DATA COLLECTION:** Importing and exploring the datasets.

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
df = pd.read_csv("Dataset.csv")
#Display the first 5 rows of dataset
df.head()
# Out:
#    Year    Country  Number_of_Tourists  Revenue  Average_Spending
# 0  2015  Country A              500000      350               700
# 1  2016  Country A              550000      385               700
# 2  2017  Country A              600000      420               700
# 3  2018  Country A              650000      455               700
# 4  2019  Country A              700000      490               700

# %%
#Display the last 5 rows of dataset
df.tail()
# Out:
#     Year    Country  Number_of_Tourists  Revenue  Average_Spending
# 43  2016  Country H              570000      399               700
# 44  2017  Country H              590000      413               700
# 45  2018  Country H              610000      427               700
# 46  2019  Country H              630000      441               700
# 47  2020  Country H              300000      210               700

# %%
df.shape#print shape(row,column)
# Out:
# (48, 5)

# %% [markdown]
# ### **2. DATA CLEANING:** Handling missing values and incorrect data.

# %%
#Check for missing values
df.isnull()
# Out:
#      Year  Country  Number_of_Tourists  Revenue  Average_Spending
# 0   False    False               False    False             False
# 1   False    False               False    False             False
# 2   False    False               False    False             False
# 3   False    False               False    False             False
# 4   False    False               False    False             False
# 5   False    False               False    False             False
# 6   False    False               False    False             False
# 7   False    False               False    False             False
# 8   False    False               False    False             False
# 9   False    False               False    False             False
# 10  False    False               False    False             False
# 11  False    False               False    False             False
# 12  False    False               False    False             False
# ...

# %%
df.isnull().sum()
# Out:
# Year                  0
# Country               0
# Number_of_Tourists    0
# Revenue               0
# Average_Spending      0
# dtype: int64

# %%
#Removing if any null value present
df.dropna(inplace=True)

# %%
#Discovering duplicates
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
#Removing duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### **3. DATA ANALYSIS:**  Analyzing trends, patterns, and relationships.

# %%
df.describe()
# Out:
#               Year  Number_of_Tourists     Revenue  Average_Spending
# count    48.000000           48.000000   48.000000              48.0
# mean   2017.500000       489166.666667  342.416667             700.0
# std       1.725898       128524.082243   89.966858               0.0
# min    2015.000000       200000.000000  140.000000             700.0
# 25%    2016.000000       407500.000000  285.250000             700.0
# 50%    2017.500000       505000.000000  353.500000             700.0
# 75%    2019.000000       592500.000000  414.750000             700.0
# max    2020.000000       700000.000000  490.000000             700.0

# %%
df.info()#checks what kind of datas are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                48 non-null     int64
#  1   Country             48 non-null     object
#  2   Number_of_Tourists  48 non-null     int64
#  3   Revenue             48 non-null     int64
#  4   Average_Spending    48 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.0+ KB

# %%
# Analyze trends, e.g., number of tourists over time
tourists_trend = df.groupby('Year')['Number_of_Tourists'].sum()
print("\nNumber of tourists over time:")
print(tourists_trend)
# Out:
# Number of tourists over time:
# Year
# 2015    3850000
# 2016    4070000
# 2017    4270000
# 2018    4460000
# 2019    4650000
# 2020    2180000
# Name: Number_of_Tourists, dtype: int64

# %%
# Analyze relationships, e.g., tourists vs. revenue
correlation = df['Number_of_Tourists'].corr(df['Revenue'])
print("\nCorrelation between number of tourists and revenue:", correlation)
# Out:
# Correlation between number of tourists and revenue: 1.0

# %%
sns.boxplot(data=df, x='Number_of_Tourists', y='Revenue')
plt.title("Relationship between Tourists and Revenue")
plt.show()

# %%
# Analyze the average spending per tourist over the years for each country
df['Spending_per_Tourist'] = df['Revenue'] / df['Number_of_Tourists']
average_spending = df.groupby(['Year', 'Country'])['Spending_per_Tourist'].mean()
print("\nAverage spending per tourist over the years for each country:")
print(average_spending)
# Out:
# Average spending per tourist over the years for each country:
# Year  Country
# 2015  Country A    0.0007
#       Country B    0.0007
#       Country C    0.0007
#       Country D    0.0007
#       Country E    0.0007
#       Country F    0.0007
#       Country G    0.0007
#       Country H    0.0007
# 2016  Country A    0.0007
#       Country B    0.0007
#       Country C    0.0007
#       Country D    0.0007
#       Country E    0.0007
#       Country F    0.0007
#       Country G    0.0007
#       Country H    0.0007
# 2017  Country A    0.0007
#       Country B    0.0007
#       Country C    0.0007
#       Country D    0.0007
#       Country E    0.0007
#       Country F    0.0007
#       Country G    0.0007
#       Country H    0.0007
# 2018  Country A    0.0007
#       Country B    0.0007
#       Country C    0.0007
#       Country D    0.0007
#       Country E    0.0007
#       Country F    0.0007
#       Country G    0.0007
#       Country H    0.0007
# ...

# %%
# Analyzing the total revenue generated by each country over the given period
total_revenue = df.groupby('Country')['Revenue'].sum()
print("\nTotal revenue generated by each country:")
print(total_revenue)
# Out:
# Total revenue generated by each country:
# Country
# Country A    2310
# Country B    1785
# Country C    1519
# Country D    1897
# Country E    2275
# Country F    2478
# Country G    1897
# Country H    2275
# Name: Revenue, dtype: int64

# %%
# Analyzing the yearly change in the number of tourists for each country
df['Tourists_Change'] = df.groupby('Country')['Number_of_Tourists'].diff()
print("\nYearly change in the number of tourists for each country:")
print(df[['Year', 'Country', 'Tourists_Change']].dropna())
# Out:
# Yearly change in the number of tourists for each country:
#     Year    Country  Tourists_Change
# 1   2016  Country A          50000.0
# 2   2017  Country A          50000.0
# 3   2018  Country A          50000.0
# 4   2019  Country A          50000.0
# 5   2020  Country A        -400000.0
# 7   2016  Country B          50000.0
# 8   2017  Country B          30000.0
# 9   2018  Country B          20000.0
# 10  2019  Country B          20000.0
# 11  2020  Country B        -320000.0
# 13  2016  Country C          20000.0
# 14  2017  Country C          20000.0
# 15  2018  Country C          20000.0
# 16  2019  Country C          20000.0
# 17  2020  Country C        -210000.0
# 19  2016  Country D          20000.0
# 20  2017  Country D          20000.0
# 21  2018  Country D          20000.0
# 22  2019  Country D          20000.0
# 23  2020  Country D        -270000.0
# 25  2016  Country E          20000.0
# 26  2017  Country E          20000.0
# 27  2018  Country E          20000.0
# ...

# %% [markdown]
# ### **4.DATA VISUALIZATION:**  Creating visual representations of the data.

# %%
# Group data by Year and sum the number of tourists
tourists_trend = df.groupby('Year')['Number_of_Tourists'].sum().reset_index()

# Plot the number of tourists over time using a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=tourists_trend, x='Year', y='Number_of_Tourists', palette='rainbow',hue='Number_of_Tourists')
plt.title('Number of Tourists Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Tourists')
plt.show()

# %%
# Plot the number of tourists over time
plt.figure(figsize=(8, 8))
sns.lineplot(data=df, x='Year', y='Number_of_Tourists', hue='Country')
plt.title('Number of Tourists Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Tourists')
plt.legend(title='Country')
plt.show()

# %%
# Plot revenue distribution
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Country', y='Revenue',palette='pastel',hue='Country')
plt.title('Revenue Distribution by Country')
plt.xlabel('Country')
plt.ylabel('Revenue')
plt.show()

# %%
#Distribution of Tourists by Country
tourists_by_country = df.groupby('Country')['Number_of_Tourists'].sum()
plt.figure(figsize=(10, 8))
plt.pie(tourists_by_country, labels=tourists_by_country.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Wistia', len(tourists_by_country)),shadow=True,)
plt.title('Distribution of Tourists by Country')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### **5.Conclusion:**  Summarizing insights and findings

# %%
print("\nConclusion:")
print("1. The total number of tourists and revenue trends over the years show that tourism is growing.")
print("2. There is a positive correlation between the number of tourists and revenue, indicating that more tourists result in higher revenue.")
print("3. The average spending per tourist varies across countries and years, reflecting differences in tourist behavior and economic conditions.")
print("4. The analysis of total revenue generated by each country identifies the top-performing tourist destinations.")
print("5. The yearly change in the number of tourists shows the dynamics of tourism growth or decline for each country.")
# Out:
# Conclusion:
# 1. The total number of tourists and revenue trends over the years show that tourism is growing.
# 2. There is a positive correlation between the number of tourists and revenue, indicating that more tourists result in higher revenue.
# 3. The average spending per tourist varies across countries and years, reflecting differences in tourist behavior and economic conditions.
# 4. The analysis of total revenue generated by each country identifies the top-performing tourist destinations.
# 5. The yearly change in the number of tourists shows the dynamics of tourism growth or decline for each country.

# %% [markdown]
# ### **Thank You**
